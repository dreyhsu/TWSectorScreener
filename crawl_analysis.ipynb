# %%
import pandas as pd

# %%
df = pd.read_pickle('data/screener_data.pkl')

# %%
df[['代號', '名稱', '漲跌 幅','產業別', '主要業務']].sort_values(by=['產業別', '漲跌 幅'])
# Out:
#       代號      名稱   漲跌 幅       產業別  \
# 9   3615      安可  +1.54       光電業
# 8   3455      由田  +4.89       光電業
# 20  6405      悅城  -1.86       光電業
# 26  8064      東捷  -2.85       光電業
# 25  8021      尖點  +4.65     其他電子業
# 23  6658      聯策   +4.9     其他電子業
# 24  6667     信紘科  -1.88     其他電子業
# 21  6415  矽力*-KY  +3.47      半導體業
# 29  9935     慶豐富  +0.28      居家生活
# 16  5603      陸海  -1.11       航運業
# 13  5202      力新   -5.8     資訊服務業
# 2   2332      友訊  +0.76     通信網路業
# 5   3081      聯亞  +4.35     通信網路業
# 3   2345      智邦  +4.56     通信網路業
# 22  6588    東典光電  -1.57     通信網路業
# 1   1432     大魯閣  +1.57      運動休閒
# 17  6158      禾昌   +0.3    電子零組件業
# 28  8249      菱光  +0.75    電子零組件業
# 19  6220      岳豐  +2.25    電子零組件業
# 7   3290      東浦  +6.42    電子零組件業
# 11  4545      銘鈺  -2.17    電子零組件業
# 10  4527     方土霖  -3.96      電機機械
# 12  4931     新盛力   +3.3  電腦及週邊設備業
# 14  5386      青雲  +9.81  電腦及週邊設備業
# 15  5438      東友  +9.97  電腦及週邊設備業
# 27  8114     振樺電  -1.37  電腦及週邊設備業
# ...
