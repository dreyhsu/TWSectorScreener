# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from FinMind.data import DataLoader

# %%
api = DataLoader()
api.login_by_token(api_token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRlIjoiMjAyNC0wNi0wMSAxMjowNzoyOSIsInVzZXJfaWQiOiJkcmVfaHN1IiwiaXAiOiIzNS4yMzMuMTk5LjIyNyJ9.vdbfK7J1TixjHvBcrk4hZuFtc3oy_cpD6wNurTQuQ7o')

# %%
stock_df = pd.read_csv(r'C:\Users\User\Downloads\StockList.csv')
stock_df = stock_df.rename(columns={"代號":"stock_id"})
stock_df['stock_id'] = stock_df['stock_id'].apply(lambda x: x.replace("=", '').replace('"', ''))
stock_df.head()
# Out:
#    排名 stock_id   名稱      成交      最高      最低   漲跌價   漲跌幅   更新日期  5日最高股價(元)  \
# 0   1     6199   天品   62.00   62.90   61.00  0.90  1.47  08/16      65.90
# 1   2     8043  蜜望實   46.40   49.00   46.00  1.50  3.34  08/16      49.00
# 2   3     5364  力麗店   35.50   36.95   34.75 -0.65 -1.80  08/16      36.95
# 3   4     2524   京城  124.00  129.00  121.50  3.00  2.48  08/16     129.00
# 4   5     3230   錦明   33.25   34.85   31.75  0.55  1.68  08/16      34.85
#
#    ...  5日最低股價(元)  現距5日低點漲幅  10日最高股價(元)  現距10日高點跌幅  10日最低股價(元)  現距10日低點漲幅  \
# 0  ...      59.50       4.2       65.90      -5.92       39.10       58.6
# 1  ...      35.50      30.7       49.00      -5.31       26.80       73.1
# 2  ...      28.50      24.6       36.95      -3.92       22.10       60.6
# 3  ...     105.00      18.1      129.00      -3.88       89.40       38.7
# 4  ...      23.15      43.6       34.85      -4.59       18.55       79.2
#
#    1個月最高股價(元)  現距1個月高點跌幅  1個月最低股價(元)  現距1個月低點漲幅
# 0       65.90      -5.92       27.25      128.0
# 1       49.00      -5.31       24.00       93.3
# 2       36.95      -3.92       18.80       88.8
# 3      129.00      -3.88       67.90       82.6
# 4       34.85      -4.59       18.55       79.2
#
# [5 rows x 21 columns]

# %%
def get_data(equity_id):
    today_obj = datetime.now()
    today_str = today_obj.strftime('%Y-%m-%d')
    two_month_str = (today_obj - timedelta(days=365)).strftime('%Y-%m-%d')
    try:
        df = pd.read_pickle(f'data/{equity_id}.pkl')
    except:
        df = api.taiwan_stock_daily(
            stock_id=equity_id,
            start_date=two_month_str,
            end_date=today_str
        )
        df.to_pickle(f'data/{equity_id}.pkl')
for equity_id in stock_df['stock_id'].unique()[:100]:
    print(equity_id)
    get_data(equity_id)
# Out:
# 2024-08-19 23:21:59.775 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 6199
# 6199
# 2024-08-19 23:22:02.857 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 8043
# 8043
# 2024-08-19 23:22:06.285 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 5364
# 5364
# 2024-08-19 23:22:09.125 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 2524
# 2524
# 2024-08-19 23:22:11.491 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3230
# 3230
# 2024-08-19 23:22:16.434 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 2924
# 2924
# 2024-08-19 23:22:20.166 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 4513
# 4513
# 2024-08-19 23:22:23.726 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 6877
# 6877
# 2024-08-19 23:22:26.263 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3663
# 3663
# 2024-08-19 23:22:30.163 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3284
# 3284
# 2024-08-19 23:22:33.274 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 2364
# 2364
# 2024-08-19 23:22:36.563 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3522
# 3522
# 2024-08-19 23:22:38.467 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3581
# 3581
# 2024-08-19 23:22:40.479 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 3219
# 3219
# 2024-08-19 23:22:42.015 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 4561
# 4561
# 2024-08-19 23:22:43.818 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 4510
# 4510
# 2024-08-19 23:22:47.455 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 4549
# 4549
# 2024-08-19 23:22:48.994 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 4562
# 4562
# 2024-08-19 23:22:51.630 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockPrice, data_id: 
handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/4716.pkl'
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connection.py:212, in HTTPConnection._new_conn(self)
#     211 except SocketTimeout as e:
# --> 212     raise ConnectTimeoutError(
#     213         self,
#     214         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     215     ) from e
#     217 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000025183AC3580>, 'Connection to api.finmindtrade.com timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.finmindtrade.com', port=443): Max retries exceeded with url: /api/v4/data?dataset=TaiwanStockPrice&data_id=4716&stock_id=&start_date=2023-08-20&end_date=2024-08-19&user_id=&password=&token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRlIjoiMjAyNC0wNi0wMSAxMjowNzoyOSIsInVzZXJfaWQiOiJkcmVfaHN1IiwiaXAiOiIzNS4yMzMuMTk5LjIyNyJ9.vdbfK7J1TixjHvBcrk4hZuFtc3oy_cpD6wNurTQuQ7o&device=package (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000025183AC3580>, 'Connection to api.finmindtrade.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\FinMind\data\finmind_api.py:24, in request_get(url, params, timeout)
#      23 try:
# ---> 24     response = requests.get(
#      25         url, verify=True, params=params, timeout=timeout
#      26     )
#      27     break
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='api.finmindtrade.com', port=443): Max retries exceeded with url: /api/v4/data?dataset=TaiwanStockPrice&data_id=4716&stock_id=&start_date=2023-08-20&end_date=2024-08-19&user_id=&password=&token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRlIjoiMjAyNC0wNi0wMSAxMjowNzoyOSIsInVzZXJfaWQiOiJkcmVfaHN1IiwiaXAiOiIzNS4yMzMuMTk5LjIyNyJ9.vdbfK7J1TixjHvBcrk4hZuFtc3oy_cpD6wNurTQuQ7o&device=package (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000025183AC3580>, 'Connection to api.finmindtrade.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 16
#      14 for equity_id in stock_df['stock_id'].unique()[:100]:
#      15     print(equity_id)
# ---> 16     get_data(equity_id)
#
# Cell In[12], line 8, in get_data(equity_id)
#       6     df = pd.read_pickle(f'data/{equity_id}.pkl')
#       7 except:
# ----> 8     df = api.taiwan_stock_daily(
#       9         stock_id=equity_id,
#      10         start_date=two_month_str,
#      11         end_date=today_str
#      12     )
#      13     df.to_pickle(f'data/{equity_id}.pkl')
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\FinMind\data\data_loader.py:94, in DataLoader.taiwan_stock_daily(self, stock_id, start_date, end_date, timeout)
#      68 def taiwan_stock_daily(
#      69     self,
#      70     stock_id: str = "",
#    (...)
#      73     timeout: int = None,
#      74 ) -> pd.DataFrame:
#      75     """get 台灣股價資料表
#      76     :param stock_id (str): 股票代號("2330")
#      77     :param start_date (str): 開始日期("2018-01-01")
#    (...)
#      92     :rtype column Trading_turnover (float)
#      93     """
# ---> 94     stock_price = self.get_data(
#      95         dataset=Dataset.TaiwanStockPrice,
#      96         data_id=stock_id,
#      97         start_date=start_date,
#      98         end_date=end_date,
#      99         timeout=timeout,
#     100     )
#     101     return stock_price
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\FinMind\data\finmind_api.py:140, in FinMindApi.get_data(self, dataset, data_id, stock_id, start_date, end_date, timeout)
#     138 url = f"{self.__api_url}/{self.__api_version}/data"
#     139 logger.debug(params)
# --> 140 response = request_get(url, params, timeout).json()
#     141 return pd.DataFrame(response["data"])
#
# File c:\Users\User\miniconda3\envs\pdf2df\lib\site-packages\FinMind\data\finmind_api.py:29, in request_get(url, params, timeout)
#      27     break
#      28 except requests.Timeout as exc:
# ---> 29     raise Exception("Timeout")
#      30 except (
#      31     requests.ConnectionError,
#      32     ssl.SSLError,
#      33     urllib3.exceptions.ReadTimeoutError,
#      34     urllib3.exceptions.ProtocolError,
#      35 ) as exc:
#      36     logger.warning(f"{exc}, retry {i} and sleep {i * 0.1} seonds")
#
# Exception: Timeout

# %%
close_df = pd.DataFrame()
for equity_id in stock_df['stock_id'].unique()[:100]:
    try:
        stock_data = pd.read_pickle(f'data/{equity_id}.pkl')
        stock_data = stock_data[['date', 'stock_id', 'close']]
        stock_data['close'].replace(0, pd.NA, inplace=True)
        stock_data['close'].ffill(inplace=True)        
        stock_data['close'].bfill(inplace=True)
        stock_data = stock_data[stock_data.date > '2024-05-20']
        close_df = pd.concat([close_df, stock_data])
    except:
        pass
close_df['close'] = close_df['close'].astype(float)

# %%
close_df
# Out:
#            date stock_id   close
# 181  2024-05-21     6199   30.05
# 182  2024-05-22     6199   29.40
# 183  2024-05-23     6199   29.90
# 184  2024-05-24     6199   30.05
# 185  2024-05-27     6199   30.00
# ..          ...      ...     ...
# 238  2024-08-13     5443  101.00
# 239  2024-08-14     5443  100.50
# 240  2024-08-15     5443  104.00
# 241  2024-08-16     5443  110.00
# 242  2024-08-19     5443  121.00
#
# [4526 rows x 3 columns]

# %%
## Example data
data = {'Stock': ['Stock', 'Stock', 'Stock', 'Stock'],
        'ClosePrice': [1, 4, 6, 3],
        'Date':['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04']}
df = pd.DataFrame(data)
df
# Out:
#    Stock  ClosePrice        Date
# 0  Stock           1  2024-01-01
# 1  Stock           4  2024-01-02
# 2  Stock           6  2024-01-03
# 3  Stock           3  2024-01-04

# %%
# Function to calculate maximum drawdown and return
def calculate_max_drawdown_return(df, window_size=20):
    results = {}
    for stock in df['stock_id'].unique():
        stock_data = df[df['stock_id'] == stock].copy()
        stock_data.set_index('date', inplace=True)
        
        # Calculate rolling maximum close price within the window
        rolling_max = stock_data['close'].rolling(window=window_size, min_periods=1).max()
        
        # Calculate drawdown
        drawdowns = stock_data['close'] / rolling_max - 1
        
        # Find the maximum drawdown
        max_drawdown = drawdowns.min()
        
        # Calculate return from the start of the window to the maximum value
        max_index = stock_data['close'].idxmax()
        max_value = stock_data.loc[max_index, 'close']
        start_value = stock_data['close'].iloc[0]
        max_return = (max_value - start_value) / start_value
        
        # Store results
        results[stock] = {'Max Drawdown': max_drawdown, 'Max Return': max_return}
    
    return pd.DataFrame.from_dict(results, orient='index')

# Calculate the max drawdown and return for a 20-day sliding window
result_df = calculate_max_drawdown_return(close_df, window_size=20)
result_df.head()
# Out:
#       Max Drawdown  Max Return
# 6199     -0.131667    1.086522
# 8043     -0.063707    0.909274
# 5364     -0.150709    1.071633
# 2524     -0.189610    1.656250
# 3230     -0.187879    1.512027

# %%
result_df.to_csv('max_drawdown.csv')

# %%
result_df.sort_values(by='Max Return', ascending=False).describe()
# Out:
#        Max Drawdown  Max Return
# count     73.000000   73.000000
# mean      -0.234813    0.789068
# std        0.084824    0.677268
# min       -0.480769    0.026549
# 25%       -0.293919    0.370709
# 50%       -0.214839    0.562570
# 75%       -0.179104    1.101138
# max       -0.063707    4.024311

# %%
result_df['Max Drawdown'].hist()
# Out:
# <Axes: >

# %%
result_df['Max Return'].hist()
# Out:
# <Axes: >

# %%
equity_id = '2359'
api = DataLoader()
today_obj = datetime.now()
today_str = today_obj.strftime('%Y-%m-%d')
# two_month_str = (today_obj - timedelta(days=1)).strftime('%Y-%m-%d')
two_month_str = datetime(2024,3,19).strftime('%Y-%m-%d')
df = api.taiwan_stock_news(
    stock_id=equity_id,
    start_date=two_month_str
)
# Out:
# 2024-08-22 11:03:31.924 | INFO     | FinMind.data.finmind_api:get_data:125 - download TaiwanStockNews, data_id: 2359

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
